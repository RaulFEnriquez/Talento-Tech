# %%
# !pip install openpyxl

# %%
import pandas as pd
import sklearn
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('Tabla_2.xlsx')
df
# Out:
#         Y  X1  X2  X3  X4
# 0    78.5   7  26   6  60
# 1    74.3   1  29  15  52
# 2   104.3  11  56   8  20
# 3    87.6  11  31   8  47
# 4    95.9   7  52   6  33
# 5   109.2  11  55   9  22
# 6   102.7   3  71  17   6
# 7    72.5   1  31  22  44
# 8    93.1   2  54  18  22
# 9   115.9  21  47   4  26
# 10   83.8   1  40  23  34
# 11  113.3  11  66   9  12
# 12  109.4  10  68   8  12

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Y       13 non-null     float64
#  1   X1      13 non-null     int64
#  2   X2      13 non-null     int64
#  3   X3      13 non-null     int64
#  4   X4      13 non-null     int64
# dtypes: float64(1), int64(4)
# memory usage: 652.0 bytes

# %%
df.describe()
# Out:
#                 Y         X1         X2         X3        X4
# count   13.000000  13.000000  13.000000  13.000000  13.00000
# mean    95.423077   7.461538  48.153846  11.769231  30.00000
# std     15.043723   5.882394  15.560881   6.405126  16.73818
# min     72.500000   1.000000  26.000000   4.000000   6.00000
# 25%     83.800000   2.000000  31.000000   8.000000  20.00000
# 50%     95.900000   7.000000  52.000000   9.000000  26.00000
# 75%    109.200000  11.000000  56.000000  17.000000  44.00000
# max    115.900000  21.000000  71.000000  23.000000  60.00000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Suponiendo que ya tienes tu DataFrame 'df' cargado

# Crear el pairplot
sns.pairplot(df)

# Mostrar el gráfico
plt.show()

# %%
from sklearn.model_selection import train_test_split

# Asumiendo que df contiene tus datos y tiene las columnas que quieres usar
# Reemplaza 'Variable1', 'Variable2', 'Variable3', 'Variable4' con los nombres reales de tus columnas
X = df[['X1', 'X2', 'X3', 'X4']] # Variables predictoras (puedes ajustar según necesites)
y = df['Y']  # Variable objetivo

# particionando en dos conjuntos _train y _test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

print("Dimensiones de X_train:", X_train.shape)
print("Dimensiones de X_test:", X_test.shape)
print("Dimensiones de y_train:", y_train.shape)
print("Dimensiones de y_test:", y_test.shape)
# Out:
# Dimensiones de X_train: (9, 4)
# Dimensiones de X_test: (4, 4)
# Dimensiones de y_train: (9,)
# Dimensiones de y_test: (4,)
